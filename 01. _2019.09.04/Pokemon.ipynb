# %%
# Importing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# File reading. 
df = pd.read_csv('https://raw.githubusercontent.com/DatasRev/source-files/master/csv/pokemon_start.csv')

# %%
# Testing.
df.head(8)
# Out:
#                         Name Type 1  Type 2  Total    HP  Attack  Defense  \
# 0                  Bulbasaur  Grass  Poison  318.0  45.0    49.0     49.0
# 1                    Ivysaur  Grass  Poison  405.0  60.0    62.0     63.0
# 2                   Venusaur  Grass  Poison  525.0  80.0    82.0     83.0
# 3      VenusaurMega Venusaur  Grass  Poison  625.0  80.0   100.0    123.0
# 4                 Charmander   Fire     NaN  309.0  39.0    52.0     43.0
# 5                 Charmeleon   Fire     NaN  405.0  58.0    64.0     58.0
# 6                  Charizard   Fire  Flying  534.0  78.0    84.0     78.0
# 7  CharizardMega Charizard X   Fire  Dragon  634.0  78.0   130.0    111.0
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0     65.0     65.0   45.0         1.0        0.0
# 1     80.0     80.0   60.0         1.0        0.0
# 2    100.0    100.0   80.0         1.0        0.0
# 3    122.0    120.0   80.0         1.0        0.0
# ...

# %%
# Info.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 12 columns):
# Name          801 non-null object
# Type 1        801 non-null object
# Type 2        414 non-null object
# Total         800 non-null float64
# HP            800 non-null float64
# Attack        800 non-null float64
# Defense       800 non-null float64
# Sp. Atk       800 non-null float64
# Sp. Def       800 non-null float64
# Speed         800 non-null float64
# Generation    800 non-null float64
# Legendary     800 non-null float64
# dtypes: float64(9), object(3)
# memory usage: 75.2+ KB

# %%
# Describe
df.describe(include='all')
# Out:
#              Name Type 1  Type 2      Total          HP      Attack  \
# count         801    801     414  800.00000  800.000000  800.000000
# unique        800     18      18        NaN         NaN         NaN
# top     Bulbasaur  Water  Flying        NaN         NaN         NaN
# freq            2    112      97        NaN         NaN         NaN
# mean          NaN    NaN     NaN  435.10250   69.258750   79.001250
# std           NaN    NaN     NaN  119.96304   25.534669   32.457366
# min           NaN    NaN     NaN  180.00000    1.000000    5.000000
# 25%           NaN    NaN     NaN  330.00000   50.000000   55.000000
# 50%           NaN    NaN     NaN  450.00000   65.000000   75.000000
# 75%           NaN    NaN     NaN  515.00000   80.000000  100.000000
# max           NaN    NaN     NaN  780.00000  255.000000  190.000000
#
#            Defense     Sp. Atk     Sp. Def       Speed  Generation  Legendary
# ...

# %%
# Filtering
df.loc[df.Name=='Bulbasaur']
# Out:
#           Name Type 1  Type 2  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    Bulbasaur  Grass  Poison  318.0  45.0    49.0     49.0     65.0     65.0
# 800  Bulbasaur  Grass     NaN    NaN   NaN     NaN      NaN      NaN      NaN
#
#      Speed  Generation  Legendary
# 0     45.0         1.0        0.0
# 800    NaN         NaN        NaN

# %%
# Dropping.
df.drop([800])
# Out:
#                           Name    Type 1  Type 2  Total     HP  Attack  \
# 0                    Bulbasaur     Grass  Poison  318.0   45.0    49.0
# 1                      Ivysaur     Grass  Poison  405.0   60.0    62.0
# 2                     Venusaur     Grass  Poison  525.0   80.0    82.0
# 3        VenusaurMega Venusaur     Grass  Poison  625.0   80.0   100.0
# 4                   Charmander      Fire     NaN  309.0   39.0    52.0
# 5                   Charmeleon      Fire     NaN  405.0   58.0    64.0
# 6                    Charizard      Fire  Flying  534.0   78.0    84.0
# 7    CharizardMega Charizard X      Fire  Dragon  634.0   78.0   130.0
# 8    CharizardMega Charizard Y      Fire  Flying  634.0   78.0   104.0
# 9                     Squirtle     Water     NaN  314.0   44.0    48.0
# 10                   Wartortle     Water     NaN  405.0   59.0    63.0
# 11                   Blastoise     Water     NaN  530.0   79.0    83.0
# ...

# %%
# Inplace
df.drop([800], inplace=True)

# %%
# Filtering.
df.loc[df.Name=='Bulbasaur']
# Out:
#         Name Type 1  Type 2  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  Bulbasaur  Grass  Poison  318.0  45.0    49.0     49.0     65.0     65.0
#
#    Speed  Generation  Legendary
# 0   45.0         1.0        0.0

# %%
# Adding new line
df=df.append({'Name' : 'Kelpie' , 'Type 1' : 'Grass',  'Type 2' :'Fairy', 'Total': 330, 'HP':60, 'Attack':30, 'Defense':40,
       'Sp. Atk':65, 'Sp. Def':55, 'Speed':5, 'Generation':2, 'Legendary':0} , ignore_index=True)

# %%
# Testing
df.tail()
# Out:
#                     Name   Type 1 Type 2  Total    HP  Attack  Defense  \
# 796  DiancieMega Diancie     Rock  Fairy  700.0  50.0   160.0    110.0
# 797  HoopaHoopa Confined  Psychic  Ghost  600.0  80.0   110.0     60.0
# 798   HoopaHoopa Unbound  Psychic   Dark  680.0  80.0   160.0     60.0
# 799            Volcanion     Fire  Water  600.0  80.0   110.0    120.0
# 800               Kelpie    Grass  Fairy  330.0  60.0    30.0     40.0
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 796    160.0    110.0  110.0         6.0        1.0
# 797    150.0    130.0   70.0         6.0        1.0
# 798    170.0    130.0   80.0         6.0        1.0
# 799    130.0     90.0   70.0         6.0        1.0
# 800     65.0     55.0    5.0         2.0        0.0

# %%
# Mininum value
df['Total'].min()
# Out:
# 180.0

# %%
# Maximum value
df['Total'].max()
# Out:
# 780.0

# %%
# Searching the line where the total = 180
df.loc[df.Total==180]
# Out:
#         Name Type 1 Type 2  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 206  Sunkern  Grass    NaN  180.0  30.0    30.0     30.0     30.0     30.0
#
#      Speed  Generation  Legendary
# 206   30.0         2.0        0.0

# %%
# Searching the Pokemon where attack is max.
f.loc[df.Total==df['Attack'].max()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-c8ce5e1d9d42> in <module>
#       1 # Searching the Pokemon where attack is max.
# ----> 2 f.loc[df.Total==df['Attack'].max()]
#
# NameError: name 'f' is not defined

# %%
# df.groupby['Generation'].agg('sum')
df.groupby(['Generation']).mean()
# Out:
#                  Total         HP     Attack    Defense    Sp. Atk    Sp. Def  \
# Generation
# 1.0         426.813253  65.819277  76.638554  70.861446  71.819277  69.090361
# 2.0         417.457944  71.102804  71.635514  73.074766  65.934579  73.728972
# 3.0         436.225000  66.543750  81.625000  74.100000  75.806250  71.225000
# 4.0         459.016529  73.082645  82.867769  78.132231  76.404959  77.190083
# 5.0         434.987879  71.787879  82.066667  72.327273  71.987879  68.739394
# 6.0         436.378049  68.268293  75.804878  76.682927  74.292683  74.890244
#
#                 Speed  Legendary
# Generation
# 1.0         72.584337   0.036145
# 2.0         61.280374   0.046729
# 3.0         66.925000   0.112500
# 4.0         71.338843   0.107438
# 5.0         68.078788   0.090909
# 6.0         66.439024   0.097561

# %%
# MAking y.
y=df.groupby(['Generation'])['Attack'].mean()

# %%
# Printing y
y
# Out:
# Generation
# 1.0    76.638554
# 2.0    71.635514
# 3.0    81.625000
# 4.0    82.867769
# 5.0    82.066667
# 6.0    75.804878
# Name: Attack, dtype: float64

# %%
# Plotting
plt.bar([1,2,3,4,5,6], y, width=0.8, align='center')
# Out:
# <Container object of 6 artists>

# %%
# Groupby types.
df.groupby(['Type 2'])['Name'].count()
# Out:
# Type 2
# Bug          3
# Dark        20
# Dragon      18
# Electric     6
# Fairy       24
# Fighting    26
# Fire        12
# Flying      97
# Ghost       14
# Grass       25
# Ground      35
# Ice         14
# Normal       4
# Poison      34
# Psychic     33
# Rock        14
# Steel       22
# Water       14
# Name: Name, dtype: int64

# %%
# Renameing.
col_rename = {'HP':'Health point'}
df = df.rename(columns=col_rename)
df.head()
# Out:
#                     Name Type 1  Type 2  Total  Health point  Attack  Defense  \
# 0              Bulbasaur  Grass  Poison  318.0          45.0    49.0     49.0
# 1                Ivysaur  Grass  Poison  405.0          60.0    62.0     63.0
# 2               Venusaur  Grass  Poison  525.0          80.0    82.0     83.0
# 3  VenusaurMega Venusaur  Grass  Poison  625.0          80.0   100.0    123.0
# 4             Charmander   Fire     NaN  309.0          39.0    52.0     43.0
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0     65.0     65.0   45.0         1.0        0.0
# 1     80.0     80.0   60.0         1.0        0.0
# 2    100.0    100.0   80.0         1.0        0.0
# 3    122.0    120.0   80.0         1.0        0.0
# 4     60.0     50.0   65.0         1.0        0.0

# %%
# Groupby Type 1 by mean
df.groupby(['Type 1']).mean()
# Out:
#                Total  Health point      Attack     Defense    Sp. Atk  \
# Type 1
# Bug       378.927536     56.884058   70.971014   70.724638  53.869565
# Dark      445.741935     66.806452   88.387097   70.225806  74.645161
# Dragon    550.531250     83.312500  112.125000   86.375000  96.843750
# Electric  443.409091     59.795455   69.090909   66.295455  90.022727
# Fairy     413.176471     74.117647   61.529412   65.705882  78.529412
# Fighting  416.444444     69.851852   96.777778   65.925926  53.111111
# Fire      458.076923     69.903846   84.769231   67.769231  88.980769
# Flying    485.000000     70.750000   78.750000   66.250000  94.250000
# Ghost     439.562500     64.437500   73.781250   81.187500  79.343750
# Grass     419.859155     67.169014   72.605634   70.366197  77.323944
# Ground    437.500000     73.781250   95.750000   84.843750  56.468750
# Ice       433.458333     72.000000   72.750000   71.416667  77.541667
# ...

# %%
# Groupby Legendary by mean
df.groupby(['Legendary']).mean()
# Out:
#                 Total  Health point      Attack    Defense     Sp. Atk  \
# Legendary
# 0.0        417.095109     67.172554   75.607337  71.516304   68.449728
# 1.0        637.384615     92.738462  116.676923  99.661538  122.184615
#
#               Sp. Def       Speed  Generation
# Legendary
# 0.0         68.873641   65.373641    3.282609
# 1.0        105.938462  100.184615    3.769231

# %%
# Scatterplot.
plt.scatter(df['Attack'], df['Defense'])

# %%
# Seaborn plot.
import seaborn as sns;
sns.set(style="ticks", color_codes=True)
ax = sns.scatterplot(x="Attack", y="Defense", hue="Type 1", s=75, data=df)
sns.set(rc={'figure.figsize':(80,80)},font_scale=5)
plt.title('Creatures')
# Set x-axis label
plt.xlabel('Attack',fontsize=40)
# Set y-axis label
plt.ylabel('Defense',fontsize=40)
# Set font size on the axes
plt.tick_params(labelsize=30)
plt.legend(loc='upper right',fontsize=40)

# %%
# Create a rank score based on the attack capabilities.
df["Attack_Rank"] = df["Attack"].rank(method ='min', ascending=False)

# %%
# Printing.
df.sort_values("Attack_Rank", inplace = True)
df.head()
# Out:
#                         Name   Type 1    Type 2  Total  Health point  Attack  \
# 163      MewtwoMega Mewtwo X  Psychic  Fighting  780.0         106.0   190.0
# 232  HeracrossMega Heracross      Bug  Fighting  600.0          80.0   185.0
# 424    GroudonPrimal Groudon   Ground      Fire  770.0         100.0   180.0
# 426    RayquazaMega Rayquaza   Dragon    Flying  780.0         105.0   180.0
# 429       DeoxysAttack Forme  Psychic       NaN  600.0          50.0   180.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Attack_Rank
# 163    100.0    154.0    100.0  130.0         1.0        1.0          1.0
# 232    115.0     40.0    105.0   75.0         2.0        0.0          2.0
# 424    160.0    150.0     90.0   90.0         3.0        1.0          3.0
# 426    100.0    180.0    100.0  115.0         3.0        1.0          3.0
# 429     20.0    180.0     20.0  150.0         3.0        1.0          3.0

# %%
# Create a rank score based on the defense capabilities.
df["Defense_Rank"] = df["Defense"].rank(method ='min', ascending=False) 
df.sort_values("Defense_Rank", inplace = True)
df.head()
# Out:
#                     Name Type 1  Type 2  Total  Health point  Attack  Defense  \
# 224  SteelixMega Steelix  Steel  Ground  610.0          75.0   125.0    230.0
# 333    AggronMega Aggron  Steel     NaN  630.0          70.0   140.0    230.0
# 230              Shuckle    Bug    Rock  505.0          20.0    10.0    230.0
# 223              Steelix  Steel  Ground  510.0          75.0    85.0    200.0
# 414             Regirock   Rock     NaN  580.0          80.0   100.0    200.0
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Attack_Rank  Defense_Rank
# 224     55.0     95.0   30.0         2.0        0.0         69.0           1.0
# 333     60.0     80.0   50.0         3.0        0.0         35.0           1.0
# 230     10.0    230.0    5.0         2.0        0.0        797.0           1.0
# 223     55.0     65.0   30.0         2.0        0.0        291.0           4.0
# 414     50.0    100.0   50.0         3.0        1.0        171.0           4.0

# %%
# Rank: Defense + Attack rank
df["AD_Rank"] =df["Defense_Rank"]+df["Attack_Rank"]

# %%
# Best pokemon?
df.loc[df["AD_Rank"] == df["AD_Rank"].min()]
# Out:
#                       Name  Type 1 Type 2  Total  Health point  Attack  \
# 424  GroudonPrimal Groudon  Ground   Fire  770.0         100.0   180.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Attack_Rank  \
# 424    160.0    150.0     90.0   90.0         3.0        1.0          3.0
#
#      Defense_Rank  AD_Rank
# 424          11.0     14.0
